# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("/Users/palaparthisainikhil/Downloads/listings.csv")

# %%
df.head()
# Out:
#       id                                name  host_id            host_name  \
# 0  77765                Superior @ Box House   417504  The Box House Hotel
# 1   2539  Clean & quiet apt home by the park     2787                 John
# 2  45910  Beautiful Queens Brownstone! - 5BR   204539                 Mark
# 3  45935        Room in Beautiful Townhouse.   204586                    L
# 4  45936  Couldn't Be Closer To Columbia Uni   867225                Rahul
#
#   neighbourhood_group        neighbourhood  latitude  longitude  \
# 0            Brooklyn           Greenpoint  40.73777  -73.95366
# 1            Brooklyn           Kensington  40.64529  -73.97238
# 2              Queens            Ridgewood  40.70309  -73.89963
# 3               Bronx           Mott Haven  40.80635  -73.92201
# 4           Manhattan  Morningside Heights  40.80630  -73.95985
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39881 entries, 0 to 39880
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              39881 non-null  int64
#  1   name                            39868 non-null  object
#  2   host_id                         39881 non-null  int64
#  3   host_name                       39831 non-null  object
#  4   neighbourhood_group             39881 non-null  object
#  5   neighbourhood                   39881 non-null  object
#  6   latitude                        39881 non-null  float64
#  7   longitude                       39881 non-null  float64
#  8   room_type                       39881 non-null  object
#  9   price                           39881 non-null  int64
#  10  minimum_nights                  39881 non-null  int64
#  11  number_of_reviews               39881 non-null  int64
# ...

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopy
from geopy.geocoders import Nominatim
import pandas as pd

longlat = pd.read_csv("/Users/palaparthisainikhil/Downloads/listings.csv")
longlat=longlat.head(1300)
geolocator = geopy.Nominatim(user_agent="check_1")

def get_zip_code(longlat, geolocator, latitude, longitude):
    try:
        location = geolocator.reverse((longlat[latitude], longlat[longitude]))
        return location.raw['address']['postcode']
    except:
        return "000"

longlat['zipcode'] = longlat.apply(get_zip_code, axis=1, geolocator=geolocator, latitude='latitude', longitude='longitude')


longlat
# Out:
#                        id                                               name  \
# 0                   77765                               Superior @ Box House
# 1                    2539                 Clean & quiet apt home by the park
# 2                   45910                 Beautiful Queens Brownstone! - 5BR
# 3                   45935                       Room in Beautiful Townhouse.
# 4                   45936                 Couldn't Be Closer To Columbia Uni
# ...                   ...                                                ...
# 39876            27577588           Luxury Studio ON Grove Street E0C - B1CA
# 39877  654151117629853651                        Lovely 3- bedroom apartment
# 39878  553754115911961053          Trendy 3-bedroom apartment near Manhattan
# 39879  698195550745703156  Luxurious private waterfront terrace, 2BR 2BA Apt
# 39880            48971505           Just Blocks to Grove PATH and JC Med Ctr
#
# ...

# %%
import geopy
from geopy.geocoders import Nominatim
import pandas as pd

longlat = pd.read_csv("/Users/palaparthisainikhil/Downloads/listings.csv")
geolocator = geopy.Nominatim(user_agent="check_1")

def get_zip_code(longlat, geolocator, latitude, longitude):
    try:
        location = geolocator.reverse((latitude, longitude))
        return location.raw['address']['postcode']
    except:
        return "000"

##longlat['zipcode'] = longlat.apply(get_zip_code, axis=1, geolocator=geolocator, latitude='latitude', longitude='longitude')

longlat["zipcode"] = " "
for i in range(len(longlat)):
    longlat["zipcode"].iloc[i]=get_zip_code(longlat,geolocator,longlat["latitude"].iloc[i],longlat["longitude"].iloc[i])

longlat
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
import geopy
from geopy.geocoders import Nominatim
import pandas as pd

longlat = pd.read_csv("/Users/palaparthisainikhil/Downloads/listings.csv")
longlat=longlat.head(3000)
geolocator = geopy.Nominatim(user_agent="check_1")

def get_zip_code(longlat, geolocator, latitude, longitude):
    try:
        location = geolocator.reverse((longlat[latitude], longlat[longitude]))
        return location.raw['address']['postcode']
    except:
        return "000"

longlat['zipcode'] = longlat.apply(get_zip_code, axis=1, geolocator=geolocator, latitude='latitude', longitude='longitude')


longlat
# Out:
#            id                                               name   host_id  \
# 0       77765                               Superior @ Box House    417504
# 1        2539                 Clean & quiet apt home by the park      2787
# 2       45910                 Beautiful Queens Brownstone! - 5BR    204539
# 3       45935                       Room in Beautiful Townhouse.    204586
# 4       45936                 Couldn't Be Closer To Columbia Uni    867225
# ...       ...                                                ...       ...
# 2995  4430819                Prime East Village One Bedroom Apt!  23002143
# 2996  4431247  1st Time/Solo/Duo Travelers!Charming Studio Sh...  22382732
# 2997  4431674                                HOME AWAY FROM HOME  21841949
# 2998  4435766                 West Village - Celebrities + LIGHT  23025661
# 2999  4436185                  Charming Park Slope Studio Sublet   3708965
#
# ...
