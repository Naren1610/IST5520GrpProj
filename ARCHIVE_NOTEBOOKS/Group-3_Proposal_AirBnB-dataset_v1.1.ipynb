# %% [markdown]
# <h1 align="center"> IST 5520 Milestone 1: Proposal </h1>
# <h3 align="center"> AirBnB Dataset </h3>
#
# <h4 align="left"> Student: Ronald Adomako </h3>
# <h4 align="left"> Student: Idris Dobbs </h3>
# <h4 align="left"> Student: Narendra Chigili </h3>
# <h4 align="left"> Student: Nikhil Srirama Sai </h3>

# %% [markdown]
# # Instruction 1: discussion and dataset

# %% [markdown]
# 1. Discuss with your group members. Choose one of the datasets provided by the
# instructor for your group project.

# %% [markdown]
# #### We chose the AirBnB dataset for New York City (NYC). We want to build a model that indicates whether hosts are charging an optimum amount for their rental.
#
# http://insideairbnb.com/new-york-city/
#
# [data dictionary](https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit?usp=sharing)
#
# http://insideairbnb.com/get-the-data
#
# http://data.insideairbnb.com/united-states/ny/new-york-city/2022-09-07/visualisations/listings.csv

# %% [markdown]
# # Instruction 2: Articles

# %% [markdown]
# Review at least three articles (peer-reviewed journal or conference articles) that are
# relevant to your selected dataset. Identify an interesting business problem that can be
# solved by using business analytics methods. Submit your project proposal.

# %% [markdown]
# ### [Analysis of Airbnb Prices using Machine Learning Techniques, Dhillon et. al, 2021](https://ieeexplore.ieee.org/document/9376144)
#
# ### [Airbnb and House Prices in Amsterdam – part-2, Charles Fried, Nov. 30, 2017](https://medium.com/mobgen/airbnb-and-house-prices-in-amsterdam-part-2-b0fd12db4ed2)
#
# ### [Insights from Airbnb dataset, Gustavo Santos, Jul 23, 2020](https://medium.com/gustavorsantos/insights-from-airbnb-dataset-7173e03a85ef)
#
# ### [Data Cleaning and EDA on Airbnb Dataset with Python Pandas and Seaborn, Soner Yıldırım, Dec 14, 2021](https://towardsdatascience.com/data-cleaning-and-eda-on-airbnb-dataset-with-python-pandas-and-seaborn-7c276116b650)

# %% [markdown]
# # Instruction 3: Proposal (Intro, Lit Rev., Hypothesis, Data)
#
# The project proposal should include four sections:
#
# • Introduction (background, business settings and scenarios etc.)
#
# • Literature Review (a brief review of at least three peer-reviewed articles relevant
# to your project)
#
# • Research Questions (what problems you intend to solve with the selected dataset)
#
# • Data (specify data source; provide a data dictionary explaining the meaning of all
# columns; explain why the dataset is appropriate for addressing your research
# questions)

# %% [markdown]
# ## Introduction

# %% [markdown]
# Business Background
#
# AirBnB is a PaaS for the short term rental market. Users use the platform to list residences for short term rentals. We noticed that for big cities, such as New York City, there are many host and some may want to use AirBnB for lucrative means. Given location and characteristics of a property, a new host would want to know whether he or she is charging the optimal amount to rent the space to lodgers.
#
# We noticed that from the New York City dataset for AirBnB, the categorical variable for location  is too coarse. The descriptor says the location is categorized into five boroughs. For a big city such as New York City, there are a lot of insights missing from a business perspective because neighborhoods vary in propertly drastically even within a single borough. Moreso, the geo-coordinates are to fine for business purposes. To handle this we implement a zip code converter to categorize properies based on their location - Feature Selection.

# %% [markdown]
# ## Literature Review

# %% [markdown]
# Review of “Insights from an Air BnB Dataset”
# This article explored the “New York City Airbnb Open Data” dataset to get more insight into price average, rent length, distribution of traffic, and reviews for different hosts and areas.
#
# Takeaways from the data analysis
# The top host name is Michael
# Most properties are in Manhattan, and half of the rentals are for the entire residence as opposed to just a room.
# The average rate is 152 dollars, and 3/4 of the observations are under 175 dollars.
# Minimum night mean is seven nights.
#
# The top rentals tend to be focused on business more so than tourism. Most of the listings are in Manhattan and Brooklyn, which allows access to the major economic and tourist activity.
#
#
# Review of “Data Cleaning and EDA on AirBnB Dataset with Python Pandas and Seaborn”
# This article explores the relationship between the list price and the host ID verification, response time, # people accommodated, # days available, amenities, and location. These observations were made based on aggregating the data and averaging the price.

# %% [markdown]
# From *Air BnB and House Prices in Amsterdam - Part 2*, by Charles Fried, the biggest take away was to predict new listings given its attributes. Fried talked about **dimensionality reduction** using t-distribution Stochastic Neighboring Embedding (t-SNE). Using t-SNE for this type of dataset lends itself to a gradual versus clear segmentation. When it comes boosting the data, weights can be applied to a host with more beds since having a more reviews leads to greater reliability of the host rating. Fried's conclusion for Amsterdam were the following:
#
# • People are willing to be farther away from the city center for cheaper accomodation - Rank 1
#
# • Traditional architecture attracts higher price and booking – Rank 2
#
# In addition, Fried points out that <u>Cleaning fee<u> is the most significant variable.

# %% [markdown]
# ## Research Question

# %% [markdown]
# What are the largest determinants / predictors of AirBnB rental prices?
#
# How can we optimize rental revenue based on rental location and other characteristics?
#
# What price should be charged based on rental location/ characteristics?

# %% [markdown]
# ## Data

# %% [markdown]
# The dataset for New York City consists of 75 columns (variables) and 39881 observations.
#
# The following is the data dictionary for all of AirBnB's data.

# %%
import pandas as pd
data = pd.read_csv('data_dictionary.csv')
pd.set_option('display.max_rows',1000)
data
# Out:
#                                            Field                       Type  \
# 0                                             id                    integer
# 1                                    listing_url                       text
# 2                                      scrape_id                     bigint
# 3                                   last_scraped                   datetime
# 4                                         source                       text
# 5                                           name                       text
# 6                                    description                       text
# 7                          neighborhood_overview                       text
# 8                                    picture_url                       text
# 9                                        host_id                    integer
# 10                                      host_url                       text
# 11                                     host_name                       text
# 12                                    host_since                       date
# 13                                 host_location                       text
# 14                                    host_about                       text
# 15                            host_response_time                        NaN
# 16                            host_response_rate                        NaN
# 17                          host_acceptance_rate                        NaN
# 18                             host_is_superhost  boolean [t=true; f=false]
# 19                            host_thumbnail_url                       text
# 20                              host_picture_url                       text
# 21                            host_neighbourhood                       text
# 22                           host_listings_count                       text
# 23                     host_total_listings_count                       text
# 24                            host_verifications                        NaN
# 25                          host_has_profile_pic  boolean [t=true; f=false]
# 26                        host_identity_verified  boolean [t=true; f=false]
# 27                                 neighbourhood                       text
# 28                        neighbourhood_cleansed                       text
# 29                  neighbourhood_group_cleansed                       text
# 30                                      latitude                    numeric
# 31                                     longitude                    numeric
# 32                                 property_type                       text
# 33                                     room_type                       text
# 34                                           NaN                        NaN
# 35                                           NaN                        NaN
# 36                                           NaN                        NaN
# 37                                           NaN                        NaN
# 38                                           NaN                        NaN
# 39                                           NaN                        NaN
# 40                                           NaN                        NaN
# 41                                           NaN                        NaN
# 42                                           NaN                        NaN
# 43                                           NaN                        NaN
# 44                                           NaN                        NaN
# 45                                           NaN                        NaN
# 46                                           NaN                        NaN
# 47                                           NaN                        NaN
# 48                                  accommodates                    integer
# 49                                     bathrooms                    numeric
# 50                                bathrooms_text                     string
# 51                                           NaN                        NaN
# 52                                      bedrooms                    integer
# 53                                          beds                    integer
# 54                                     amenities                       json
# 55                                         price                   currency
# 56                                minimum_nights                    integer
# 57                                maximum_nights                    integer
# 58                        minimum_minimum_nights                    integer
# 59                        maximum_minimum_nights                    integer
# 60                        minimum_maximum_nights                    integer
# 61                        maximum_maximum_nights                    integer
# 62                        minimum_nights_avg_ntm                    numeric
# 63                        maximum_nights_avg_ntm                    numeric
# 64                              calendar_updated                       date
# 65                              has_availability                    boolean
# 66                               availability_30                    integer
# 67                               availability_60                    integer
# 68                               availability_90                    integer
# 69                              availability_365                    integer
# 70                         calendar_last_scraped                       date
# 71                             number_of_reviews                    integer
# 72                         number_of_reviews_ltm                    integer
# 73                        number_of_reviews_l30d                    integer
# 74                                  first_review                       date
# 75                                   last_review                       date
# 76                          review_scores_rating                        NaN
# 77                        review_scores_accuracy                        NaN
# 78                     review_scores_cleanliness                        NaN
# 79                         review_scores_checkin                        NaN
# 80                   review_scores_communication                        NaN
# 81                        review_scores_location                        NaN
# 82                           review_scores_value                        NaN
# 83                                       license                       text
# 84                              instant_bookable                    boolean
# 85                calculated_host_listings_count                    integer
# 86   calculated_host_listings_count_entire_homes                    integer
# 87  calculated_host_listings_count_private_rooms                    integer
# 88   calculated_host_listings_count_shared_rooms                    integer
# 89                             reviews_per_month                    numeric
#
#    Calculated                                        Description
# 0         NaN         Airbnb's unique identifier for the listing
# 1           y                                                NaN
# 2           y            Inside Airbnb "Scrape" this was part of
# 3           y  UTC. The date and time this listing was "scrap...
# 4         NaN  One of "neighbourhood search" or "previous scr...
# 5         NaN                                Name of the listing
# 6         NaN                Detailed description of the listing
# 7         NaN            Host's description of the neighbourhood
# 8         NaN  URL to the Airbnb hosted regular sized image f...
# 9         NaN       Airbnb's unique identifier for the host/user
# 10          y                       The Airbnb page for the host
# 11        NaN  Name of the host. Usually just the first name(s).
# 12        NaN  The date the host/user was created. For hosts ...
# 13        NaN                  The host's self reported location
# 14        NaN                         Description about the host
# 15        NaN                                                NaN
# 16        NaN                                                NaN
# 17        NaN  That rate at which a host accepts booking requ...
# 18        NaN                                                NaN
# 19        NaN                                                NaN
# 20        NaN                                                NaN
# 21        NaN                                                NaN
# 22        NaN  The number of listings the host has (per Airbn...
# 23        NaN  The number of listings the host has (per Airbn...
# 24        NaN                                                NaN
# 25        NaN                                                NaN
# 26        NaN                                                NaN
# 27        NaN                                                NaN
# 28          y  The neighbourhood as geocoded using the latitu...
# 29          y  The neighbourhood group as geocoded using the ...
# 30        NaN  Uses the World Geodetic System (WGS84) project...
# 31        NaN  Uses the World Geodetic System (WGS84) project...
# 32        NaN  Self selected property type. Hotels and Bed an...
# 33        NaN   [Entire home/apt|Private room|Shared room|Hotel]
# 34        NaN                                                NaN
# 35        NaN  All homes are grouped into the following three...
# 36        NaN                                                NaN
# 37        NaN                                       Entire place
# 38        NaN                                       Private room
# 39        NaN                                        Shared room
# 40        NaN                                       Entire place
# 41        NaN  Entire places are best if you're seeking a hom...
# 42        NaN                                                NaN
# 43        NaN                                      Private rooms
# 44        NaN  Private rooms are great for when you prefer a ...
# 45        NaN                                                NaN
# 46        NaN                                       Shared rooms
# 47        NaN  Shared rooms are for when you don't mind shari...
# 48        NaN                The maximum capacity of the listing
# 49        NaN             The number of bathrooms in the listing
# 50        NaN           The number of bathrooms in the listing.
# 51        NaN  On the Airbnb web-site, the bathrooms field ha...
# 52        NaN                             The number of bedrooms
# 53        NaN                               The number of bed(s)
# 54        NaN                                                NaN
# 55        NaN                      daily price in local currency
# 56        NaN  minimum number of night stay for the listing (...
# 57        NaN  maximum number of night stay for the listing (...
# 58          y  the smallest minimum_night value from the cale...
# 59          y  the largest minimum_night value from the calen...
# 60          y  the smallest maximum_night value from the cale...
# 61          y  the largest maximum_night value from the calen...
# 62          y  the average minimum_night value from the calen...
# 63          y  the average maximum_night value from the calen...
# 64        NaN                                                NaN
# 65        NaN                                  [t=true; f=false]
# 66          y  avaliability_x. The availability of the listin...
# 67          y  avaliability_x. The availability of the listin...
# 68          y  avaliability_x. The availability of the listin...
# 69          y  avaliability_x. The availability of the listin...
# 70        NaN                                                NaN
# 71        NaN              The number of reviews the listing has
# 72          y  The number of reviews the listing has (in the ...
# 73          y  The number of reviews the listing has (in the ...
# 74          y                The date of the first/oldest review
# 75          y                 The date of the last/newest review
# 76        NaN                                                NaN
# 77        NaN                                                NaN
# 78        NaN                                                NaN
# 79        NaN                                                NaN
# 80        NaN                                                NaN
# 81        NaN                                                NaN
# 82        NaN                                                NaN
# 83        NaN             The licence/permit/registration number
# 84        NaN  [t=true; f=false]. Whether the guest can autom...
# 85          y  The number of listings the host has in the cur...
# 86          y  The number of Entire home/apt listings the hos...
# 87          y  The number of Private room listings the host h...
# 88          y  The number of Shared room listings the host ha...
# 89          y  The number of reviews the listing has over the...

# %% [markdown]
# # Instruction 4: Jupyter Notebook

# %%
# !which python
# Out:
# /opt/anaconda3/envs/MyEnv/bin/python

# %%
# !which jupyter
# Out:
# /opt/anaconda3/envs/MyEnv/bin/jupyter

# %%
# !which python3
# Out:
# /opt/anaconda3/envs/MyEnv/bin/python3

# %% [markdown]
# # Instruction 5: Github Repository and Handles

# %% [markdown]
# https://github.com/Naren1610/IST5520GrpProj/
#
# ### IST5520GrpProj
#
# <h4 align="left"> Ronald Adomako, adomakor412 </h3>
# <h4 align="left"> Idris Dobbs, idobbs-2012 </h3>
# <h4 align="left"> Narendra Chigili, Naren1610 </h3>
# <h4 align="left"> Nikhil Srirama Sai, SaiNikhilPalaparthi </h3>

# %% [markdown]
# # Instruction 6: Submisssion

# %% [markdown]
# see Canvas for Group 3
