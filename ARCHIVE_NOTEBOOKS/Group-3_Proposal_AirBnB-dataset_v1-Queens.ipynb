# %% [markdown]
# <h1 align="center"> IST 5520 Milestone 1: Proposal </h1>
# <h3 align="center"> AirBnB Dataset </h3>
#
# <h4 align="left"> Student: Ronald Adomako </h3>
# <h4 align="left"> Student: Idris Dobbs </h3>
# <h4 align="left"> Student: Nikhil Srirama Sai </h3>
# <h4 align="left"> Student: Narendra Chigili </h3>

# %% [markdown]
# # Instruction 1: discussion and dataset

# %% [markdown]
# 1. Discuss with your group members. Choose one of the datasets provided by the
# instructor for your group project.

# %% [markdown]
# #### We chose the AirBnB dataset for New York City (NYC). We want to build a model that indicates whether hosts are charging an optimum amount for their rental.
#
# http://insideairbnb.com/new-york-city/
#
# https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit?usp=sharing
#
# http://insideairbnb.com/get-the-data
#
# http://data.insideairbnb.com/united-states/ny/new-york-city/2022-09-07/visualisations/listings.csv

# %% [markdown]
# # Instruction 2: Articles

# %% [markdown]
# Review at least three articles (peer-reviewed journal or conference articles) that are
# relevant to your selected dataset. Identify an interesting business problem that can be
# solved by using business analytics methods. Submit your project proposal.

# %% [markdown]
# ### [Airbnb and House Prices in Amsterdam – part-2](https://medium.com/mobgen/airbnb-and-house-prices-in-amsterdam-part-2-b0fd12db4ed2)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from time import sleep
from random import randint
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderServiceError
from logging import log

# %%
csv_URL = "http://data.insideairbnb.com/united-states/ny/new-york-city/2022-09-07/visualisations/listings.csv"
df2 = pd.read_csv(csv_URL)
df2
# Out:
#                        id                                               name  \
# 0                   77765                               Superior @ Box House
# 1                    2539                 Clean & quiet apt home by the park
# 2                   45910                 Beautiful Queens Brownstone! - 5BR
# 3                   45935                       Room in Beautiful Townhouse.
# 4                   45936                 Couldn't Be Closer To Columbia Uni
# ...                   ...                                                ...
# 39876            27577588           Luxury Studio ON Grove Street E0C - B1CA
# 39877  654151117629853651                        Lovely 3- bedroom apartment
# 39878  553754115911961053          Trendy 3-bedroom apartment near Manhattan
# 39879  698195550745703156  Luxurious private waterfront terrace, 2BR 2BA Apt
# 39880            48971505           Just Blocks to Grove PATH and JC Med Ctr
#
#          host_id            host_name neighbourhood_group  \
# 0         417504  The Box House Hotel            Brooklyn
# 1           2787                 John            Brooklyn
# 2         204539                 Mark              Queens
# 3         204586                    L               Bronx
# 4         867225                Rahul           Manhattan
# ...          ...                  ...                 ...
# 39876   37412692                  Kim           Manhattan
# 39877  117540494               Miriam              Queens
# 39878   15048320                India           Manhattan
# 39879  151487807                Asser            Brooklyn
# 39880      46201                    J           Manhattan
#
#              neighbourhood   latitude  longitude        room_type  price  \
# 0               Greenpoint  40.737770 -73.953660       Hotel room    308
# 1               Kensington  40.645290 -73.972380     Private room    299
# 2                Ridgewood  40.703090 -73.899630  Entire home/apt    425
# 3               Mott Haven  40.806350 -73.922010     Private room     60
# 4      Morningside Heights  40.806300 -73.959850     Private room     75
# ...                    ...        ...        ...              ...    ...
# 39876         Ellis Island  40.718220 -74.037940  Entire home/apt    135
# 39877             Rosedale  40.647244 -73.720088  Entire home/apt    180
# 39878      Upper West Side  40.787320 -74.004470  Entire home/apt    240
# 39879         Williamsburg  40.709192 -73.970121  Entire home/apt    400
# 39880         Ellis Island  40.718350 -74.044160     Private room     40
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0                   2                 42  2022-07-18               0.30
# 1                  30                  9  2018-10-19               0.11
# 2                  30                 13  2019-11-12               0.10
# 3                  30                  0         NaN                NaN
# 4                  31                135  2022-07-11               0.95
# ...               ...                ...         ...                ...
# 39876             365                  2  2019-09-16               0.04
# 39877               1                  5  2022-08-24               1.92
# 39878               5                 18  2022-08-22               2.87
# 39879              30                  0         NaN                NaN
# 39880               1                 15  2021-10-25               0.91
#
#        calculated_host_listings_count  availability_365  \
# 0                                  30               217
# 1                                   9               356
# 2                                   6               365
# 3                                   1                83
# 4                                   1               219
# ...                               ...               ...
# 39876                               7               365
# 39877                               1                 0
# 39878                               1               152
# 39879                               1               311
# 39880                               1                 0
#
#        number_of_reviews_ltm license
# 0                          4     NaN
# 1                          0     NaN
# 2                          0     NaN
# 3                          0     NaN
# 4                          4     NaN
# ...                      ...     ...
# 39876                      0     NaN
# 39877                      5     NaN
# 39878                     18     NaN
# 39879                      0     NaN
# 39880                      4     NaN
#
# [39881 rows x 18 columns]

# %%
import geopy
from geopy.geocoders import Nominatim

#GeoLocator = Nominatim()
# nom = Nominatim(user_agent="http")
geopy.geocoders.options.default_user_agent = "my-application"
#Nominatim(user_agent="my-application")
ip = open('mac.txt', "r")

# %%
macAdr = ip.readlines()[0]

# %%
# geolocator = geopy.Nominatim(user_agent=macAdr)
# # geolocator = geopy.Nominatim(user_agent='my-application')
# #geolocator = geopy.geocoders.options.default_user_agent = "my-application"

# def get_zipcode(df, geolocator, lat_field, lon_field):
#     location = geolocator.reverse((df[lat_field], df[lon_field]))
#     #print(location.raw['lat'])
#     #print(df)
#     return location.raw['address']['postcode']


# df = pd.DataFrame({
#     'Lat': [29.39291, 29.39923, 29.40147, 29.38752, 29.39291, 29.39537, 29.39343, 29.39291, 29.39556],
#     'Lon': [-98.50925, -98.51256, -98.51123, -98.52372, -98.50925, -98.50402, -98.49707, -98.50925, -98.53148]
# })
# zipcodes = df.apply(get_zipcode, axis=1, geolocator=geolocator, lat_field='Lat', lon_field='Lon')

# %%
#zipcodes

# %% [markdown]
# https://www.google.com/search?q=python+script+get+ip+address&oq=python+script+get+ip+address&aqs=chrome..69i57.7877j0j7&sourceid=chrome&ie=UTF-8

# %%
# !date +%c

f = open('Queens_log.txt','w+')

user_agent = 'user_me_{}'.format(randint(10000,99999))
geolocator = Nominatim(user_agent=user_agent)
# def reverse_geocode(geolocator, latlon, sleep_sec):
#     try:
#         return geolocator.reverse(latlon)
#     except GeocoderTimedOut:
#         logging.info('TIMED OUT: GeocoderTimedOut: Retrying...')
#         sleep(randint(1*100,sleep_sec*100)/100)
#         return reverse_geocode(geolocator, latlon, sleep_sec)
#     except GeocoderServiceError as e:
#         logging.info('CONNECTION REFUSED: GeocoderServiceError encountered.')
#         logging.error(e)
#         return None
#     except Exception as e:
#         logging.info('ERROR: Terminating due to exception {}'.format(e))
#         return None
    
def get_zipcode(df, geolocator, lat_field, lon_field):
    lat = df[lat_field]
    lon = df[lon_field]
    address = df
    
    row = f'Latitude: {lat}, Longitude: {lon}'
    print(row+'\n', file = f)
    
    try:
        location = geolocator.reverse((df[lat_field], df[lon_field]))       
        return location.raw['address']['postcode']
    except GeocoderTimedOut:
        # !date +%c
        #logging.info('TIMED OUT: GeocoderTimedOut: Retrying...')
        print(f'TIMED OUT: GeocoderTimedOut: Retrying...')
        sleep(randint(1*100,sleep_sec*100)/100)
        print(f'Latitude: {lat}, \
                Longitude: {lon}, \
                Location: {address}')
        return get_zipcode(df, geolocator, lat_field, lon_field)
        
    except GeocoderServiceError as e:
        # !date +%c
        #logging.info('CONNECTION REFUSED: GeocoderServiceError encountered.')
        #logging.error(e)
        print(f'CONNECTION REFUSED: GeocoderServiceError encountered.')
        print(e)
        print(f'Latitude: {lat}, \
                Longitude: {lon}, \
                Location: {address}')
        return None
    except Exception as e:
        # !date +%c
        #logging.info('ERROR: Terminating due to exception {}'.format(e))
        print(f'ERROR: Terminating due to exception {e}')
        print(f'Latitude: {lat}, \
                Longitude: {lon}, \
                Location: {address}')
        return None

df_Queens = df2[df2['neighbourhood_group']=='Queens']

df = pd.DataFrame({
    'Lat': df_Queens['latitude'],
    'Lon': df_Queens['longitude']
})

zipcodes = df.apply(get_zipcode,
                    axis=1,
                    geolocator=geolocator,
                    lat_field='Lat',
                    lon_field='Lon')

# !date +%c

f.close()

df_Queens_zipcodes = df_Queens
df_Queens_zipcodes['ZipCodes'] = zipcodes

df_Queens_zipcodes.to_csv('Queens_zipcodes.csv')
# Out:
# Sat Oct 29 13:25:15 2022
# Sat Oct 29 13:25:18 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.70309&lon=-73.89963&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.70309,                 Longitude: -73.89963,                 Location: Lat    40.70309
# Lon   -73.89963
# Name: 2, dtype: float64
# Sat Oct 29 13:25:22 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.77868&lon=-73.90652&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.77868,                 Longitude: -73.90652,                 Location: Lat    40.77868
# Lon   -73.90652
# Name: 26, dtype: float64
# Sat Oct 29 13:25:26 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.71567&lon=-73.87842&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.71567,                 Longitude: -73.87842,                 Location: Lat    40.71567
# Lon   -73.87842
# Name: 27, dtype: float64
# Sat Oct 29 13:25:30 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.70422&lon=-73.89778&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.70422,                 Longitude: -73.89778,                 Location: Lat    40.70422
# Lon   -73.89778
# Name: 28, dtype: float64
# Sat Oct 29 13:25:34 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.71778&lon=-73.87714&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.71778,                 Longitude: -73.87714,                 Location: Lat    40.71778
# Lon   -73.87714
# Name: 29, dtype: float64
# Sat Oct 29 13:25:38 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.67144&lon=-73.76501&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.67144,                 Longitude: -73.76501,                 Location: Lat    40.67144
# Lon   -73.76501
# Name: 41, dtype: float64
# Sat Oct 29 13:25:41 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# Non-successful status code 404
# Latitude: 40.74757,                 Longitude: -73.94571,                 Location: Lat    40.74757
# Lon   -73.94571
# Name: 54, dtype: float64
# Sat Oct 29 13:25:41 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# Non-successful status code 404
# Latitude: 40.772472,                 Longitude: -73.906075,                 Location: Lat    40.772472
# Lon   -73.906075
# Name: 66, dtype: float64
# Sat Oct 29 13:25:44 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# Non-successful status code 404
# Latitude: 40.58603,                 Longitude: -73.8145,                 Location: Lat    40.58603
# Lon   -73.81450
# Name: 79, dtype: float64
# Sat Oct 29 13:25:45 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# Non-successful status code 404
# Latitude: 40.70271,                 Longitude: -73.8993,                 Location: Lat    40.70271
# Lon   -73.89930
# Name: 82, dtype: float64
# Sat Oct 29 13:25:47 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# Non-successful status code 404
# Latitude: 40.7106,                 Longitude: -73.85246,                 Location: Lat    40.71060
# Lon   -73.85246
# Name: 159, dtype: float64
# Sat Oct 29 13:25:48 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# Non-successful status code 404
# Latitude: 40.76336,                 Longitude: -73.92099,                 Location: Lat    40.76336
# Lon   -73.92099
# Name: 195, dtype: float64
# Sat Oct 29 13:25:52 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.74523&lon=-73.92318&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.74523,                 Longitude: -73.92318,                 Location: Lat    40.74523
# Lon   -73.92318
# Name: 198, dtype: float64
# Sat Oct 29 13:25:56 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.75684&lon=-73.91286&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.75684,                 Longitude: -73.91286,                 Location: Lat    40.75684
# Lon   -73.91286
# Name: 221, dtype: float64
# Sat Oct 29 13:26:00 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.77507&lon=-73.93367&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.77507,                 Longitude: -73.93367,                 Location: Lat    40.77507
# Lon   -73.93367
# Name: 234, dtype: float64
# Sat Oct 29 13:26:04 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.7012&lon=-73.83151&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.7012,                 Longitude: -73.83151,                 Location: Lat    40.70120
# Lon   -73.83151
# Name: 269, dtype: float64
# Sat Oct 29 13:26:08 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.77728&lon=-73.91278&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.77728,                 Longitude: -73.91278,                 Location: Lat    40.77728
# Lon   -73.91278
# Name: 335, dtype: float64
# Sat Oct 29 13:26:13 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.73849&lon=-73.87232&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.73849,                 Longitude: -73.87232,                 Location: Lat    40.73849
# Lon   -73.87232
# Name: 358, dtype: float64
# Sat Oct 29 13:26:17 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.73877&lon=-73.92557&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.73877,                 Longitude: -73.92557,                 Location: Lat    40.73877
# Lon   -73.92557
# Name: 398, dtype: float64
# Sat Oct 29 13:26:21 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.73333&lon=-73.85933&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.73333,                 Longitude: -73.85933,                 Location: Lat    40.73333
# Lon   -73.85933
# Name: 400, dtype: float64
# Sat Oct 29 13:26:25 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.70167&lon=-73.90927&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.70167,                 Longitude: -73.90927,                 Location: Lat    40.70167
# Lon   -73.90927
# Name: 401, dtype: float64
# Sat Oct 29 13:26:29 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.75537&lon=-73.77159&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Latitude: 40.75537,                 Longitude: -73.77159,                 Location: Lat    40.75537
# Lon   -73.77159
# Name: 412, dtype: float64
# Sat Oct 29 13:26:30 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# Non-successful status code 404
# Latitude: 40.76716,                 Longitude: -73.91177,                 Location: Lat    40.76716
# Lon   -73.91177
# Name: 415, dtype: float64
# Sat Oct 29 13:26:31 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# Non-successful status code 404
# Latitude: 40.74536,                 Longitude: -73.94903,                 Location: Lat    40.74536
# Lon   -73.94903
# Name: 421, dtype: float64
# Sat Oct 29 13:26:34 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# Non-successful status code 404
# Latitude: 40.74496,                 Longitude: -73.91167,                 Location: Lat    40.74496
# Lon   -73.91167
# Name: 427, dtype: float64
# Sat Oct 29 13:26:36 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# Non-successful status code 404
# Latitude: 40.70749,                 Longitude: -73.916,                 Location: Lat    40.70749
# Lon   -73.91600
# Name: 444, dtype: float64
# Sat Oct 29 13:26:39 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# Non-successful status code 404
# Latitude: 40.67144,                 Longitude: -73.76501,                 Location: Lat    40.67144
# Lon   -73.76501
# Name: 462, dtype: float64
# Sat Oct 29 13:26:40 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# Non-successful status code 404
# Latitude: 40.77128,                 Longitude: -73.91939,                 Location: Lat    40.77128
# Lon   -73.91939
# Name: 469, dtype: float64
# Sat Oct 29 13:26:42 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# Non-successful status code 404
# Latitude: 40.74499,                 Longitude: -73.95372,                 Location: Lat    40.74499
# Lon   -73.95372
# Name: 475, dtype: float64
# Sat Oct 29 13:26:45 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# Non-successful status code 404
# Latitude: 40.70148,                 Longitude: -73.82972,                 Location: Lat    40.70148
# Lon   -73.82972
# Name: 476, dtype: float64
# Sat Oct 29 13:26:47 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.77539&lon=-73.91709&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9e7610>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.77539,                 Longitude: -73.91709,                 Location: Lat    40.77539
# Lon   -73.91709
# Name: 492, dtype: float64
# Sat Oct 29 13:26:48 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.71215&lon=-73.81692&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9d4950>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.71215,                 Longitude: -73.81692,                 Location: Lat    40.71215
# Lon   -73.81692
# Name: 497, dtype: float64
# Sat Oct 29 13:26:49 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.71044&lon=-73.81703&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9c7b50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.71044,                 Longitude: -73.81703,                 Location: Lat    40.71044
# Lon   -73.81703
# Name: 500, dtype: float64
# Sat Oct 29 13:26:50 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.72678&lon=-73.90448&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd986b10>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.72678,                 Longitude: -73.90448,                 Location: Lat    40.72678
# Lon   -73.90448
# Name: 518, dtype: float64
# Sat Oct 29 13:26:50 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.75434&lon=-73.9354&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9d4d50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.75434,                 Longitude: -73.9354,                 Location: Lat    40.75434
# Lon   -73.93540
# Name: 523, dtype: float64
# Sat Oct 29 13:26:51 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.74709&lon=-73.92056&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9e7310>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.74709,                 Longitude: -73.92056,                 Location: Lat    40.74709
# Lon   -73.92056
# Name: 551, dtype: float64
# Sat Oct 29 13:26:52 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.7464&lon=-73.94807&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9dc990>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.7464,                 Longitude: -73.94807,                 Location: Lat    40.74640
# Lon   -73.94807
# Name: 571, dtype: float64
# Sat Oct 29 13:26:53 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.76763&lon=-73.77003&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9d71d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.76763,                 Longitude: -73.77003,                 Location: Lat    40.76763
# Lon   -73.77003
# Name: 584, dtype: float64
# Sat Oct 29 13:26:53 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.75347&lon=-73.89145&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd96d290>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.75347,                 Longitude: -73.89145,                 Location: Lat    40.75347
# Lon   -73.89145
# Name: 590, dtype: float64
# Sat Oct 29 13:26:54 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.699&lon=-73.90295&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd96db10>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.699,                 Longitude: -73.90295,                 Location: Lat    40.69900
# Lon   -73.90295
# Name: 596, dtype: float64
# Sat Oct 29 13:26:55 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.75243&lon=-73.87843&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9dc5d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.75243,                 Longitude: -73.87843,                 Location: Lat    40.75243
# Lon   -73.87843
# Name: 615, dtype: float64
# Sat Oct 29 13:26:55 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.74944&lon=-73.89292&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dc882850>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.74944,                 Longitude: -73.89292,                 Location: Lat    40.74944
# Lon   -73.89292
# Name: 616, dtype: float64
# Sat Oct 29 13:26:56 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.77266&lon=-73.92268&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9d4990>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.77266,                 Longitude: -73.92268,                 Location: Lat    40.77266
# Lon   -73.92268
# Name: 626, dtype: float64
# Sat Oct 29 13:26:57 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.69941&lon=-73.90576&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9c7650>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.69941,                 Longitude: -73.90576,                 Location: Lat    40.69941
# Lon   -73.90576
# Name: 654, dtype: float64
# Sat Oct 29 13:26:57 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.70499&lon=-73.90128&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9c72d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.70499,                 Longitude: -73.90128,                 Location: Lat    40.70499
# Lon   -73.90128
# Name: 678, dtype: float64
# Sat Oct 29 13:26:58 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.74506&lon=-73.91251&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9e7850>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.74506,                 Longitude: -73.91251,                 Location: Lat    40.74506
# Lon   -73.91251
# Name: 679, dtype: float64
# Sat Oct 29 13:26:59 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.67595&lon=-73.76463&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9dcdd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.67595,                 Longitude: -73.76463,                 Location: Lat    40.67595
# Lon   -73.76463
# Name: 683, dtype: float64
# Sat Oct 29 13:27:00 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.75702&lon=-73.91682&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd96ded0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.75702,                 Longitude: -73.91682,                 Location: Lat    40.75702
# Lon   -73.91682
# Name: 709, dtype: float64
# Sat Oct 29 13:27:00 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.75912&lon=-73.919&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9d4810>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.75912,                 Longitude: -73.919,                 Location: Lat    40.75912
# Lon   -73.91900
# Name: 737, dtype: float64
# Sat Oct 29 13:27:01 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.70873&lon=-73.91732&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9861d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.70873,                 Longitude: -73.91732,                 Location: Lat    40.70873
# Lon   -73.91732
# Name: 741, dtype: float64
# Sat Oct 29 13:27:02 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.75485&lon=-73.81795&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd96ded0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.75485,                 Longitude: -73.81795,                 Location: Lat    40.75485
# Lon   -73.81795
# Name: 753, dtype: float64
# Sat Oct 29 13:27:03 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.69958&lon=-73.90251&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9dc610>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.69958,                 Longitude: -73.90251,                 Location: Lat    40.69958
# Lon   -73.90251
# Name: 770, dtype: float64
# Sat Oct 29 13:27:03 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.73589&lon=-73.92457&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd9e7610>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.73589,                 Longitude: -73.92457,                 Location: Lat    40.73589
# Lon   -73.92457
# Name: 776, dtype: float64
# Sat Oct 29 13:27:04 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.76797&lon=-73.91625&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa6dd986090>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Latitude: 40.76797,                 Longitude: -73.91625,                 Location: Lat    40.76797
# Lon   -73.91625
# Name: 785, dtype: float64
# Sat Oct 29 13:27:05 2022
