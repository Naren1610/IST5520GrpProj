# %% [markdown]
# <h1 align="center"> IST 5520 Milestone 1: Proposal </h1>
# <h3 align="center"> AirBnB Dataset </h3>
#
# <h4 align="left"> Student: Ronald Adomako </h3>
# <h4 align="left"> Student: Idris Dobbs </h3>
# <h4 align="left"> Student: Nikhil Srirama Sai </h3>
# <h4 align="left"> Student: Narendra Chigili </h3>

# %% [markdown]
# # Instruction 1: discussion and dataset

# %% [markdown]
# 1. Discuss with your group members. Choose one of the datasets provided by the
# instructor for your group project.

# %% [markdown]
# #### We chose the AirBnB dataset for New York City (NYC). We want to build a model that indicates whether hosts are charging an optimum amount for their rental.
#
# http://insideairbnb.com/new-york-city/
#
# https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit?usp=sharing
#
# http://insideairbnb.com/get-the-data
#
# http://data.insideairbnb.com/united-states/ny/new-york-city/2022-09-07/visualisations/listings.csv

# %% [markdown]
# # Instruction 2: Articles

# %% [markdown]
# Review at least three articles (peer-reviewed journal or conference articles) that are
# relevant to your selected dataset. Identify an interesting business problem that can be
# solved by using business analytics methods. Submit your project proposal.

# %% [markdown]
# ### [Airbnb and House Prices in Amsterdam – part-2](https://medium.com/mobgen/airbnb-and-house-prices-in-amsterdam-part-2-b0fd12db4ed2)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
csv_URL = "http://data.insideairbnb.com/united-states/ny/new-york-city/2022-09-07/visualisations/listings.csv"
df2 = pd.read_csv(csv_URL)
df2
# Out:
#                        id                                               name  \
# 0                   77765                               Superior @ Box House
# 1                    2539                 Clean & quiet apt home by the park
# 2                   45910                 Beautiful Queens Brownstone! - 5BR
# 3                   45935                       Room in Beautiful Townhouse.
# 4                   45936                 Couldn't Be Closer To Columbia Uni
# ...                   ...                                                ...
# 39876            27577588           Luxury Studio ON Grove Street E0C - B1CA
# 39877  654151117629853651                        Lovely 3- bedroom apartment
# 39878  553754115911961053          Trendy 3-bedroom apartment near Manhattan
# 39879  698195550745703156  Luxurious private waterfront terrace, 2BR 2BA Apt
# 39880            48971505           Just Blocks to Grove PATH and JC Med Ctr
#
#          host_id            host_name neighbourhood_group  \
# 0         417504  The Box House Hotel            Brooklyn
# 1           2787                 John            Brooklyn
# 2         204539                 Mark              Queens
# 3         204586                    L               Bronx
# 4         867225                Rahul           Manhattan
# ...          ...                  ...                 ...
# 39876   37412692                  Kim           Manhattan
# 39877  117540494               Miriam              Queens
# 39878   15048320                India           Manhattan
# 39879  151487807                Asser            Brooklyn
# 39880      46201                    J           Manhattan
#
#              neighbourhood   latitude  longitude        room_type  price  \
# 0               Greenpoint  40.737770 -73.953660       Hotel room    308
# 1               Kensington  40.645290 -73.972380     Private room    299
# 2                Ridgewood  40.703090 -73.899630  Entire home/apt    425
# 3               Mott Haven  40.806350 -73.922010     Private room     60
# 4      Morningside Heights  40.806300 -73.959850     Private room     75
# ...                    ...        ...        ...              ...    ...
# 39876         Ellis Island  40.718220 -74.037940  Entire home/apt    135
# 39877             Rosedale  40.647244 -73.720088  Entire home/apt    180
# 39878      Upper West Side  40.787320 -74.004470  Entire home/apt    240
# 39879         Williamsburg  40.709192 -73.970121  Entire home/apt    400
# 39880         Ellis Island  40.718350 -74.044160     Private room     40
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0                   2                 42  2022-07-18               0.30
# 1                  30                  9  2018-10-19               0.11
# 2                  30                 13  2019-11-12               0.10
# 3                  30                  0         NaN                NaN
# 4                  31                135  2022-07-11               0.95
# ...               ...                ...         ...                ...
# 39876             365                  2  2019-09-16               0.04
# 39877               1                  5  2022-08-24               1.92
# 39878               5                 18  2022-08-22               2.87
# 39879              30                  0         NaN                NaN
# 39880               1                 15  2021-10-25               0.91
#
#        calculated_host_listings_count  availability_365  \
# 0                                  30               217
# 1                                   9               356
# 2                                   6               365
# 3                                   1                83
# 4                                   1               219
# ...                               ...               ...
# 39876                               7               365
# 39877                               1                 0
# 39878                               1               152
# 39879                               1               311
# 39880                               1                 0
#
#        number_of_reviews_ltm license
# 0                          4     NaN
# 1                          0     NaN
# 2                          0     NaN
# 3                          0     NaN
# 4                          4     NaN
# ...                      ...     ...
# 39876                      0     NaN
# 39877                      5     NaN
# 39878                     18     NaN
# 39879                      0     NaN
# 39880                      4     NaN
#
# [39881 rows x 18 columns]

# %%
#csv_URL = "http://data.insideairbnb.com/united-states/ny/new-york-city/2022-09-07/visualisations/listings.csv"
#df = pd.read_csv('./listings.csv')
# df

# %%
#df.info()

# %%
#df['host_location']

# %%
import geopy
from geopy.geocoders import Nominatim

#GeoLocator = Nominatim()
# nom = Nominatim(user_agent="http")
geopy.geocoders.options.default_user_agent = "my-application"
#Nominatim(user_agent="my-application")
ip = open('mac.txt', "r")

# %%
macAdr = ip.readlines()[0]

# %%
geolocator = geopy.Nominatim(user_agent=macAdr)
# geolocator = geopy.Nominatim(user_agent='my-application')
#geolocator = geopy.geocoders.options.default_user_agent = "my-application"

def get_zipcode(df, geolocator, lat_field, lon_field):
    location = geolocator.reverse((df[lat_field], df[lon_field]))
    #print(location.raw['lat'])
    #print(df)
    return location.raw['address']['postcode']


df = pd.DataFrame({
    'Lat': [29.39291, 29.39923, 29.40147, 29.38752, 29.39291, 29.39537, 29.39343, 29.39291, 29.39556],
    'Lon': [-98.50925, -98.51256, -98.51123, -98.52372, -98.50925, -98.50402, -98.49707, -98.50925, -98.53148]
})
zipcodes = df.apply(get_zipcode, axis=1, geolocator=geolocator, lat_field='Lat', lon_field='Lon')
# Out:
# Lat    29.39291
# Lon   -98.50925
# Name: 0, dtype: float64
# Lat    29.39923
# Lon   -98.51256
# Name: 1, dtype: float64
# Lat    29.40147
# Lon   -98.51123
# Name: 2, dtype: float64
# Lat    29.38752
# Lon   -98.52372
# Name: 3, dtype: float64
# Lat    29.39291
# Lon   -98.50925
# Name: 4, dtype: float64
# Lat    29.39537
# Lon   -98.50402
# Name: 5, dtype: float64
# Lat    29.39343
# Lon   -98.49707
# Name: 6, dtype: float64
# Lat    29.39291
# Lon   -98.50925
# Name: 7, dtype: float64
# Lat    29.39556
# Lon   -98.53148
# Name: 8, dtype: float64

# %%
zipcodes
# Out:
# 0    78204
# 1    78204
# 2    78204
# 3    78225
# 4    78204
# 5    78204
# 6    78204
# 7    78204
# 8    78225
# dtype: object

# %%
# !date +%c

ip = open('mac.txt', "r")
macAdr = ip.readlines()[0]

geolocator = geopy.Nominatim(user_agent=macAdr)
# geolocator = geopy.Nominatim(user_agent='my-application')
#geolocator = geopy.geocoders.options.default_user_agent = "my-application"

def get_zipcode(df, geolocator, lat_field, lon_field):
    location = geolocator.reverse((df[lat_field], df[lon_field]))
    return location.raw['address']['postcode']


df = pd.DataFrame({
    'Lat': df2['latitude'],
    'Lon': df2['longitude']
})
# !date +%c

# %%
# !date +%c

for obs in df.index:
    location = geolocator.reverse((df['Lat'][obs], df['Lon'][obs]))
    try:
        location.raw['address']['postcode']
    except ValueError as e:
        print(obs)
        print (e)
        
        address = location.raw['address']
        print (f'Location: {address}')
        
        postcode = location.raw['address']['postcode']
        print (f'Location: {postcode}')

# !date +%c
# Out:
# Sat Oct 15 16:57:59 2022
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# OSError: [Errno 50] Network is down
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     171             raise NewConnectionError(
# --> 172                 self, "Failed to establish a new connection: %s" % e
#     173             )
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fb2250a0c50>: Failed to establish a new connection: [Errno 50] Network is down
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     766                 body_pos=body_pos,
# --> 767                 **response_kw
#     768             )
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     766                 body_pos=body_pos,
# --> 767                 **response_kw
#     768             )
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     726             retries = retries.increment(
# --> 727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     728             )
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.719&lon=-73.99764&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb2250a0c50>: Failed to establish a new connection: [Errno 50] Network is down'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/geopy/adapters.py in _request(self, url, timeout, headers)
#     447         try:
# --> 448             resp = self.session.get(url, timeout=timeout, headers=headers)
#     449         except Exception as error:
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.719&lon=-73.99764&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb2250a0c50>: Failed to establish a new connection: [Errno 50] Network is down'))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# <ipython-input-84-f17dbf83a002> in <module>
#       2
#       3 for obs in df.index:
# ----> 4     location = geolocator.reverse((df['Lat'][obs], df['Lon'][obs]))
#       5     try:
#       6         location.raw['address']['postcode']
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/geopy/geocoders/nominatim.py in reverse(self, query, exactly_one, timeout, language, addressdetails, zoom)
#     360         logger.debug("%s.reverse: %s", self.__class__.__name__, url)
#     361         callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 362         return self._call_geocoder(url, callback, timeout=timeout)
#     363
#     364     def _parse_code(self, place):
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, callback, timeout, is_json, headers)
#     366         try:
#     367             if is_json:
# --> 368                 result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369             else:
#     370                 result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/geopy/adapters.py in get_json(self, url, timeout, headers)
#     436
#     437     def get_json(self, url, *, timeout, headers):
# --> 438         resp = self._request(url, timeout=timeout, headers=headers)
#     439         try:
#     440             return resp.json()
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/geopy/adapters.py in _request(self, url, timeout, headers)
#     458                     raise GeocoderServiceError(message)
#     459                 else:
# --> 460                     raise GeocoderUnavailable(message)
#     461             elif isinstance(error, requests.Timeout):
#     462                 raise GeocoderTimedOut("Service timed out")
#
# GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.719&lon=-73.99764&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb2250a0c50>: Failed to establish a new connection: [Errno 50] Network is down'))

# %%
location = geolocator.reverse((40.719, -73.99764))
location.raw['address']['postcode']
# Out:
# '10013'

# %%
df2[df2['latitude']==40.719]
# Out:
#              id                                               name   host_id  \
# 326      288726                                 Cozy Railroad Apt.    107853
# 1205    1018529                     Large 2 BDRM @ McCarren Park!!   5606448
# 4238    6555997                 Sunny, Clean & Spacious in the LES  11513446
# 7673   12184956                Private Room in Greenpoint Brooklyn  36959636
# 12775  22191121               Cute 2-BR in Greenpoint/Williamsburg   6963310
# 13209  22979825    Private large bedroom in Prime Williamsburg, BK  10826049
# 39454  54352579  Luxury JerseyCity Penthouse Statue of Liberty ...  49313463
#
#         host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 326           Flo           Manhattan     Little Italy    40.719  -73.99764
# 1205         Pete            Brooklyn     Williamsburg    40.719  -73.94831
# 4238        Erica           Manhattan  Lower East Side    40.719  -73.99451
# 7673   Panagiotis            Brooklyn     Williamsburg    40.719  -73.94709
# 12775     Kenneth            Brooklyn     Williamsburg    40.719  -73.94772
# 13209        Faye            Brooklyn       Greenpoint    40.719  -73.95275
# 39454     Charlie           Manhattan     Ellis Island    40.719  -74.03990
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 326       Private room    109               4                 58  2021-09-07
# 1205   Entire home/apt    300              30                 77  2022-08-20
# 4238   Entire home/apt    150              30                  2  2016-01-01
# 7673      Private room     75              30                  0         NaN
# 12775  Entire home/apt    100               3                  1  2017-12-27
# 13209     Private room     75              30                  0         NaN
# 39454  Entire home/apt    218               1                 18  2022-07-24
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 326                 0.48                               1                 0
# 1205                0.67                               1               182
# 4238                0.02                               1                 0
# 7673                 NaN                               1                 0
# 12775               0.02                               1                 0
# 13209                NaN                               1                 0
# 39454               3.67                               3                 6
#
#        number_of_reviews_ltm license
# 326                        1     NaN
# 1205                       2     NaN
# 4238                       0     NaN
# 7673                       0     NaN
# 12775                      0     NaN
# 13209                      0     NaN
# 39454                     18     NaN

# %%
df2[df2['latitude']==40.719][df2['longitude']== -73.99764]
# Out:
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          id                name  host_id host_name neighbourhood_group  \
# 326  288726  Cozy Railroad Apt.   107853       Flo           Manhattan
#
#     neighbourhood  latitude  longitude     room_type  price  minimum_nights  \
# 326  Little Italy    40.719  -73.99764  Private room    109               4
#
#      number_of_reviews last_review  reviews_per_month  \
# 326                 58  2021-09-07               0.48
#
#      calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 326                               1                 0                      1
#
#     license
# 326     NaN

# %%
#https://www.google.com/search?q=python+script+get+ip+address&oq=python+script+get+ip+address&aqs=chrome..69i57.7877j0j7&sourceid=chrome&ie=UTF-8

# %%
# !date +%c

from time import sleep
from random import randint
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderServiceError

user_agent = 'user_me_{}'.format(randint(10000,99999))
geolocator = Nominatim(user_agent=user_agent)
# def reverse_geocode(geolocator, latlon, sleep_sec):
#     try:
#         return geolocator.reverse(latlon)
#     except GeocoderTimedOut:
#         logging.info('TIMED OUT: GeocoderTimedOut: Retrying...')
#         sleep(randint(1*100,sleep_sec*100)/100)
#         return reverse_geocode(geolocator, latlon, sleep_sec)
#     except GeocoderServiceError as e:
#         logging.info('CONNECTION REFUSED: GeocoderServiceError encountered.')
#         logging.error(e)
#         return None
#     except Exception as e:
#         logging.info('ERROR: Terminating due to exception {}'.format(e))
#         return None
    
def get_zipcode(df, geolocator, lat_field, lon_field):
    lat = df[lat_field]
    lon = df[lon_field]
    address = df
    try:
        location = geolocator.reverse((df[lat_field], df[lon_field]))       
        return location.raw['address']['postcode']
    except GeocoderTimedOut:
        # !date +%c
        #logging.info('TIMED OUT: GeocoderTimedOut: Retrying...')
        print(f'TIMED OUT: GeocoderTimedOut: Retrying...')
        sleep(randint(1*100,sleep_sec*100)/100)
        print(f'Latitude: {lat}, \
                Longitude: {lon}, \
                Location: {address}')
        return get_zipcode(df, geolocator, lat_field, lon_field)
        
    except GeocoderServiceError as e:
        # !date +%c
        #logging.info('CONNECTION REFUSED: GeocoderServiceError encountered.')
        #logging.error(e)
        print(f'CONNECTION REFUSED: GeocoderServiceError encountered.')
        print(e)
        print(f'Latitude: {lat}, \
                Longitude: {lon}, \
                Location: {address}')
        return None
    except Exception as e:
        # !date +%c
        #logging.info('ERROR: Terminating due to exception {}'.format(e))
        print(f'ERROR: Terminating due to exception {e}')
        print(f'Latitude: {lat}, \
                Longitude: {lon}, \
                Location: {address}')
        #return None


df = pd.DataFrame({
    'Lat': df2['latitude'],
    'Lon': df2['longitude']
})

zipcodes = df.apply(get_zipcode,
                    axis=1,
                    geolocator=geolocator,
                    lat_field='Lat',
                    lon_field='Lon')

# !date +%c
# Out:
# Sat Oct 15 18:12:40 2022
# Sat Oct 15 18:28:33 2022
# ERROR: Terminating due to exception 'postcode'
# Latitude: 40.72913,                 Longitude: -74.00234,                 Location: Lat    40.72913
# Lon   -74.00234
# Name: 1110, dtype: float64
# Sat Oct 15 18:52:29 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.80389&lon=-73.94945&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb2220e8790>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Latitude: 40.80389,                 Longitude: -73.94945,                 Location: Lat    40.80389
# Lon   -73.94945
# Name: 1134, dtype: float64
# Sat Oct 15 18:52:29 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.80825&lon=-73.94124&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb2220e4110>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Latitude: 40.80825,                 Longitude: -73.94124,                 Location: Lat    40.80825
# Lon   -73.94124
# Name: 1135, dtype: float64
# Sat Oct 15 18:52:29 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.76423&lon=-73.91891&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb2220e8e90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Latitude: 40.76423,                 Longitude: -73.91891,                 Location: Lat    40.76423
# Lon   -73.91891
# Name: 1136, dtype: float64
# Sat Oct 15 18:52:30 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.68759&lon=-73.99754&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb225024850>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Latitude: 40.68759,                 Longitude: -73.99754,                 Location: Lat    40.68759
# Lon   -73.99754
# Name: 1137, dtype: float64
# Sat Oct 15 18:52:30 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.73046&lon=-73.98181&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb225136690>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Latitude: 40.73046,                 Longitude: -73.98181,                 Location: Lat    40.73046
# Lon   -73.98181
# Name: 1138, dtype: float64
# Sat Oct 15 18:52:30 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.74946&lon=-73.88288&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb224f76510>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Latitude: 40.74946,                 Longitude: -73.88288,                 Location: Lat    40.74946
# Lon   -73.88288
# Name: 1139, dtype: float64
# Sat Oct 15 18:52:30 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.68669&lon=-73.97744&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb2251a24d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Latitude: 40.68669,                 Longitude: -73.97744,                 Location: Lat    40.68669
# Lon   -73.97744
# Name: 1140, dtype: float64
# Sat Oct 15 18:52:30 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.76273&lon=-73.98306&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb2220e8d90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Latitude: 40.76273,                 Longitude: -73.98306,                 Location: Lat    40.76273
# Lon   -73.98306
# Name: 1141, dtype: float64
# Sat Oct 15 18:52:31 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.7417&lon=-73.82203&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb2220e8210>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Latitude: 40.7417,                 Longitude: -73.82203,                 Location: Lat    40.74170
# Lon   -73.82203
# Name: 1142, dtype: float64
# Sat Oct 15 18:52:31 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.67911&lon=-73.9833&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb2250244d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Latitude: 40.67911,                 Longitude: -73.9833,                 Location: Lat    40.67911
# Lon   -73.98330
# Name: 1143, dtype: float64
# Sat Oct 15 19:35:22 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.78158&lon=-73.94808&format=json&addressdetails=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb22211d7d0>: Failed to establish a new connection: [Errno 50] Network is down'))
# Latitude: 40.78158,                 Longitude: -73.94808,                 Location: Lat    40.78158
# Lon   -73.94808
# Name: 1811, dtype: float64
# Sat Oct 15 19:35:29 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.67867&lon=-73.84136&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb22297f250>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# Latitude: 40.67867,                 Longitude: -73.84136,                 Location: Lat    40.67867
# Lon   -73.84136
# Name: 1812, dtype: float64
# Sat Oct 15 19:35:35 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.75937&lon=-73.99161&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb224cd9f50>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# Latitude: 40.75937,                 Longitude: -73.99161,                 Location: Lat    40.75937
# Lon   -73.99161
# Name: 1813, dtype: float64
# Sat Oct 15 19:35:41 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.67086&lon=-73.94563&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb224cd91d0>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# Latitude: 40.67086,                 Longitude: -73.94563,                 Location: Lat    40.67086
# Lon   -73.94563
# Name: 1814, dtype: float64
# Sat Oct 15 19:35:48 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.73364&lon=-73.99708&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb224cee910>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# Latitude: 40.73364,                 Longitude: -73.99708,                 Location: Lat    40.73364
# Lon   -73.99708
# Name: 1815, dtype: float64
# Sat Oct 15 19:35:54 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.66244&lon=-73.94514&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb224cd9dd0>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# Latitude: 40.66244,                 Longitude: -73.94514,                 Location: Lat    40.66244
# Lon   -73.94514
# Name: 1816, dtype: float64
# Sat Oct 15 19:36:00 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.78518&lon=-73.97068&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb22297ff50>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# Latitude: 40.78518,                 Longitude: -73.97068,                 Location: Lat    40.78518
# Lon   -73.97068
# Name: 1817, dtype: float64
# Sat Oct 15 19:36:06 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.67403&lon=-73.94139&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb225136c10>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# Latitude: 40.67403,                 Longitude: -73.94139,                 Location: Lat    40.67403
# Lon   -73.94139
# Name: 1818, dtype: float64
# Sat Oct 15 19:36:13 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.68311&lon=-73.91108&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb224f1c050>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# Latitude: 40.68311,                 Longitude: -73.91108,                 Location: Lat    40.68311
# Lon   -73.91108
# Name: 1819, dtype: float64
# Sat Oct 15 19:36:19 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.78583&lon=-73.9771&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb22297c490>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# Latitude: 40.78583,                 Longitude: -73.9771,                 Location: Lat    40.78583
# Lon   -73.97710
# Name: 1820, dtype: float64
# Sat Oct 15 19:36:25 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.67726&lon=-73.9491&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb224edb750>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# Latitude: 40.67726,                 Longitude: -73.9491,                 Location: Lat    40.67726
# Lon   -73.94910
# Name: 1821, dtype: float64
# Sat Oct 15 19:36:31 2022
# CONNECTION REFUSED: GeocoderServiceError encountered.
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.79726&lon=-73.96885&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb224f76bd0>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# Latitude: 40.79726,                 Longitude: -73.96885,                 Location: Lat    40.79726
# Lon   -73.96885
# Name: 1822, dtype: float64
# Sat Oct 15 19:37:55 2022
# ERROR: Terminating due to exception 'postcode'
# Latitude: 40.75808,                 Longitude: -73.97088,                 Location: Lat    40.75808
# Lon   -73.97088
# Name: 1985, dtype: float64
# Sat Oct 15 19:45:30 2022
# ERROR: Terminating due to exception 'postcode'
# Latitude: 40.68264,                 Longitude: -73.96243,                 Location: Lat    40.68264
# Lon   -73.96243
# Name: 2832, dtype: float64
# Sat Oct 15 19:48:10 2022
# ERROR: Terminating due to exception 'postcode'
# Latitude: 40.69279,                 Longitude: -73.9771,                 Location: Lat    40.69279
# Lon   -73.97710
# Name: 3145, dtype: float64
# Sat Oct 15 20:08:32 2022
# ERROR: Terminating due to exception 'postcode'
# Latitude: 40.73023530794889,                 Longitude: -73.97860684563116,                 Location: Lat    40.730235
# Lon   -73.978607
# Name: 5561, dtype: float64
# Sat Oct 15 20:17:00 2022
# ERROR: Terminating due to exception 'postcode'
# Latitude: 40.71567,                 Longitude: -74.00611,                 Location: Lat    40.71567
# Lon   -74.00611
# Name: 6550, dtype: float64
# Sat Oct 15 20:17:17 2022
# ERROR: Terminating due to exception 'postcode'
# Latitude: 40.69278,                 Longitude: -73.97421,                 Location: Lat    40.69278
# Lon   -73.97421
# Name: 6573, dtype: float64
# Sat Oct 15 20:23:55 2022
# ERROR: Terminating due to exception 'postcode'
# Latitude: 40.69294,                 Longitude: -73.97432,                 Location: Lat    40.69294
# Lon   -73.97432
# Name: 7336, dtype: float64
# Sat Oct 15 20:25:23 2022
# ERROR: Terminating due to exception 'postcode'
# Latitude: 40.77611,                 Longitude: -73.98987,                 Location: Lat    40.77611
# Lon   -73.98987
# Name: 7513, dtype: float64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-113-ea952482dae6> in <module>
#      69                     geolocator=geolocator,
#      70                     lat_field='Lat',
# ---> 71                     lon_field='Lon')
#      72
#      73 get_ipython().system('date +%c')
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/pandas/core/apply.py in f(x)
#     129
#     130             def f(x):
# --> 131                 return func(x, *args, **kwargs)
#     132
#     133         else:
#
# <ipython-input-113-ea952482dae6> in get_zipcode(df, geolocator, lat_field, lon_field)
#      28     address = df
#      29     try:
# ---> 30         location = geolocator.reverse((df[lat_field], df[lon_field]))
#      31         return location.raw['address']['postcode']
#      32     except GeocoderTimedOut:
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/geopy/geocoders/nominatim.py in reverse(self, query, exactly_one, timeout, language, addressdetails, zoom)
#     360         logger.debug("%s.reverse: %s", self.__class__.__name__, url)
#     361         callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 362         return self._call_geocoder(url, callback, timeout=timeout)
#     363
#     364     def _parse_code(self, place):
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, callback, timeout, is_json, headers)
#     366         try:
#     367             if is_json:
# --> 368                 result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369             else:
#     370                 result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/geopy/adapters.py in get_json(self, url, timeout, headers)
#     436
#     437     def get_json(self, url, *, timeout, headers):
# --> 438         resp = self._request(url, timeout=timeout, headers=headers)
#     439         try:
#     440             return resp.json()
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/geopy/adapters.py in _request(self, url, timeout, headers)
#     446     def _request(self, url, *, timeout, headers):
#     447         try:
# --> 448             resp = self.session.get(url, timeout=timeout, headers=headers)
#     449         except Exception as error:
#     450             message = str(error)
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/http/client.py in getresponse(self)
#    1367         try:
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#    1371                 self.close()
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/http/client.py in begin(self)
#     308         # read until we get a non-100 response
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#     312                 break
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/http/client.py in _read_status(self)
#     269
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#     273             raise LineTooLong("status line")
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /opt/anaconda3/envs/MyEnv/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
zipcodes
# Out:
# 0    78204
# 1    78204
# 2    78204
# 3    78225
# 4    78204
# 5    78204
# 6    78204
# 7    78204
# 8    78225
# dtype: object
